# %%
import pandas as pd
import seaborn as sns 
import numpy as np
import glob
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Import FPKM, MAF_protein and isoform switch files for required cancer type

#Filenames
MAF_file = '/Users/jake/OneDrive - University of Glasgow/Project/COAD/GeneExpression_MAF/COAD_MAF_protein_coding_full.csv'
FPKM_protein_file = '/Users/jake/OneDrive - University of Glasgow/Project/COAD/GeneExpression_MAF/COAD_FPKM_protein_all.csv'
isoform_switch_file = '/Users/jake/OneDrive - University of Glasgow/Project/COAD/isoform_switch/COAD_isoform_switches_ensembl.csv'

#Read in as dataframes
MAF_protein = pd.read_csv(MAF_file,low_memory=False,sep=',',index_col=0)
FPKM_protein = pd.read_csv(FPKM_protein_file,header=[0,1],low_memory=False,sep='\t',index_col=[0])
isoform_switches = pd.read_csv(isoform_switch_file,sep='\t')

# %%
isoform_switches
# Out:
#    Gene_symbol  ensembl_gene_id  entrezgene_id chromosome_name
# 2         CTTN  ENSG00000085733           2017              11
# 3        FBLN2  ENSG00000163520           2199               3
# 4         FLNA  ENSG00000196924           2316               X
# 5      ARHGEF9  ENSG00000131089          23229               X
# 6     SLC39A14  ENSG00000104635          23516               8
# 7     ATP6V1C2  ENSG00000143882         245973               2
# 9         ISLR  ENSG00000129009           3671              15
# 11       MYH11  ENSG00000133392           4629              16
# 12         SRI  ENSG00000075142           6717               7
# 13        UGP2  ENSG00000169764           7360               2
# 14       IL1R2  ENSG00000115590           7850               2
# 15       HKDC1  ENSG00000156510          80201              10
# 16        CD44  ENSG00000026508            960              11

# %%
FPKM_protein.head()
# Out:
# Gene_symbol                             A1BG            A1CF             A2M  \
# Gene_ensembl_id              ENSG00000121410 ENSG00000148584 ENSG00000175899
# Sample_ID
# TCGA-AA-3867-01A-01R-1022-07        0.052551        2.477200       57.378073
# TCGA-CA-6719-01A-11R-1839-07        0.005613        1.927244       74.944713
# TCGA-NH-A50V-01A-11R-A28H-07        0.035237        0.550182       51.276491
# TCGA-AA-A01C-01A-01R-A00A-07        0.049092        1.914795       45.653386
# TCGA-AA-A02F-01A-01R-A089-07        0.011685        1.145542       28.787736
#
# Gene_symbol                            A2ML1         A3GALT2          A4GALT  \
# Gene_ensembl_id              ENSG00000166535 ENSG00000184389 ENSG00000128274
# Sample_ID
# TCGA-AA-3867-01A-01R-1022-07        0.021620             0.0        5.347004
# TCGA-CA-6719-01A-11R-1839-07        0.012317             0.0        4.271353
# TCGA-NH-A50V-01A-11R-A28H-07        0.024852             0.0        5.097944
# TCGA-AA-A01C-01A-01R-A00A-07        0.013464             0.0        5.011742
# TCGA-AA-A02F-01A-01R-A089-07        0.006410             0.0        2.099586
#
# Gene_symbol                            A4GNT            AAAS            AACS  \
# Gene_ensembl_id              ENSG00000118017 ENSG00000094914 ENSG00000081760
# Sample_ID
# TCGA-AA-3867-01A-01R-1022-07        0.000000       10.124001        3.888190
# TCGA-CA-6719-01A-11R-1839-07        0.025395       11.569886        1.872340
# TCGA-NH-A50V-01A-11R-A28H-07        0.056933       10.462945        3.612377
# TCGA-AA-A01C-01A-01R-A00A-07        0.000000       15.683433        3.708620
# TCGA-AA-A02F-01A-01R-A089-07        0.000000       15.396349        2.902797
#
# Gene_symbol                            AADAC  ...            ZW10  \
# Gene_ensembl_id              ENSG00000114771  ... ENSG00000086827
# Sample_ID                                     ...
# TCGA-AA-3867-01A-01R-1022-07        0.031552  ...        8.337702
# TCGA-CA-6719-01A-11R-1839-07        1.159435  ...       10.875540
# TCGA-NH-A50V-01A-11R-A28H-07        0.193436  ...        7.953033
# TCGA-AA-A01C-01A-01R-A00A-07        0.117902  ...        7.460225
# TCGA-AA-A02F-01A-01R-A089-07        0.028064  ...        7.259496
#
# Gene_symbol                           ZWILCH           ZWINT            ZXDA  \
# Gene_ensembl_id              ENSG00000174442 ENSG00000122952 ENSG00000198205
# Sample_ID
# TCGA-AA-3867-01A-01R-1022-07        3.266961       11.951200        0.844530
# TCGA-CA-6719-01A-11R-1839-07        6.107697       11.915234        1.711313
# TCGA-NH-A50V-01A-11R-A28H-07        1.813204       14.288954        1.255144
# TCGA-AA-A01C-01A-01R-A00A-07        3.650127       22.783866        1.123639
# TCGA-AA-A02F-01A-01R-A089-07       11.352859       21.240253        1.650287
#
# Gene_symbol                             ZXDB            ZXDC          ZYG11A  \
# Gene_ensembl_id              ENSG00000198455 ENSG00000070476 ENSG00000203995
# Sample_ID
# TCGA-AA-3867-01A-01R-1022-07        2.250194        4.091899        0.011212
# TCGA-CA-6719-01A-11R-1839-07        4.772996        4.795855        0.009581
# TCGA-NH-A50V-01A-11R-A28H-07        4.156986        5.492997        0.038664
# TCGA-AA-A01C-01A-01R-A00A-07        2.886182        3.341388        0.000000
# TCGA-AA-A02F-01A-01R-A089-07        4.630294        6.636417        0.000000
#
# Gene_symbol                           ZYG11B             ZYX           ZZEF1
# Gene_ensembl_id              ENSG00000162378 ENSG00000159840 ENSG00000074755
# Sample_ID
# TCGA-AA-3867-01A-01R-1022-07        3.216321       87.952703        2.923495
# TCGA-CA-6719-01A-11R-1839-07        5.434010       72.500361        5.158080
# TCGA-NH-A50V-01A-11R-A28H-07        3.399480       57.827137        3.430372
# TCGA-AA-A01C-01A-01R-A00A-07        2.662764      116.008374        5.140081
# TCGA-AA-A02F-01A-01R-A089-07        5.230433       68.590155        2.939338
#
# [5 rows x 19538 columns]

# %%
#Check for genes not present in FPKM_protein 

display(set(isoform_switches['ensembl_gene_id']) - set(FPKM_protein.columns.levels[1]))
display (set(isoform_switches['Gene_symbol']) - set(FPKM_protein.columns.levels[0]) )
# Out:
# set()
# set()

# %%
# Note that gene names / symbols can still be different 
# => filter in relation to Ensembl ID
#drop any Ensembl IDs from isoform switch dataframe that not present in FPKM

#missing_genes = list(set(isoform_switches['ensembl_gene_id']) - set(FPKM_protein.columns.levels[1]))
#isoform_switches = isoform_switches.loc[~isoform_switches['ensembl_gene_id'].isin(missing_genes)]

# %%
#Create list of isoform gene_names / columns to keep in FPKM
#ADD 'Cancer' TO LIST since = target variable

cols_to_keep = list(isoform_switches['ensembl_gene_id'])
cols_to_keep.append('Cancer')

# %%
#Filter FPKM for the isoform switch genes

FPKM_protein_isoform = FPKM_protein.loc(axis=1)[:, cols_to_keep]

# %%
FPKM_protein_isoform
# Out:
# Gene_symbol                             CTTN           FBLN2            FLNA  \
# Gene_ensembl_id              ENSG00000085733 ENSG00000163520 ENSG00000196924
# Sample_ID
# TCGA-AA-3867-01A-01R-1022-07       43.419941       17.969730       98.506992
# TCGA-CA-6719-01A-11R-1839-07       31.008285        5.075141      153.793369
# TCGA-NH-A50V-01A-11R-A28H-07       49.971597        7.463640       48.447111
# TCGA-AA-A01C-01A-01R-A00A-07       43.526294       11.790653      150.463581
# TCGA-AA-A02F-01A-01R-A089-07       23.395513        2.266629       75.349062
# ...                                      ...             ...             ...
# TCGA-A6-2682-11A-01R-A32Z-07       36.195520        9.756399       40.254574
# TCGA-AA-3522-11A-01R-A32Z-07       38.606857       16.125248       45.252554
# TCGA-AA-3662-11A-01R-1723-07       31.916105       21.770961       92.316274
# TCGA-AA-3520-11A-01R-A32Z-07       36.031825       20.685962       45.642212
# TCGA-A6-2685-11A-01R-A32Z-07       45.048101       10.234471       86.369411
#
# Gene_symbol                          ARHGEF9        SLC39A14        ATP6V1C2  \
# Gene_ensembl_id              ENSG00000131089 ENSG00000104635 ENSG00000143882
# Sample_ID
# TCGA-AA-3867-01A-01R-1022-07        2.116260       22.918339        2.374979
# TCGA-CA-6719-01A-11R-1839-07        2.724855       16.831717        1.542474
# TCGA-NH-A50V-01A-11R-A28H-07        2.982264       12.825033        1.674405
# TCGA-AA-A01C-01A-01R-A00A-07        2.773046       20.000358        4.851438
# TCGA-AA-A02F-01A-01R-A089-07        2.261290       20.654395        2.605318
# ...                                      ...             ...             ...
# TCGA-A6-2682-11A-01R-A32Z-07        5.116727       27.502997        0.668204
# TCGA-AA-3522-11A-01R-A32Z-07        5.323429       31.354408        0.477939
# TCGA-AA-3662-11A-01R-1723-07        6.593554       28.567929        1.115913
# TCGA-AA-3520-11A-01R-A32Z-07        4.815894       29.933660        0.531336
# TCGA-A6-2685-11A-01R-A32Z-07        5.925887       33.403523        0.601481
#
# Gene_symbol                             ISLR           MYH11             SRI  \
# Gene_ensembl_id              ENSG00000129009 ENSG00000133392 ENSG00000075142
# Sample_ID
# TCGA-AA-3867-01A-01R-1022-07       69.811483       24.526326       44.841315
# TCGA-CA-6719-01A-11R-1839-07       42.516880       60.857761       38.171138
# TCGA-NH-A50V-01A-11R-A28H-07       51.739143        5.664525       24.658549
# TCGA-AA-A01C-01A-01R-A00A-07       58.313480       15.126343       43.792638
# TCGA-AA-A02F-01A-01R-A089-07       10.410286        6.824040       27.200675
# ...                                      ...             ...             ...
# TCGA-A6-2682-11A-01R-A32Z-07        7.510906       17.512665      116.629904
# TCGA-AA-3522-11A-01R-A32Z-07       10.783217       24.119451      153.386318
# TCGA-AA-3662-11A-01R-1723-07       16.008965      125.767640       69.142586
# TCGA-AA-3520-11A-01R-A32Z-07       11.140504       25.517808      142.960271
# TCGA-A6-2685-11A-01R-A32Z-07        8.336189       72.659643      103.210964
#
# Gene_symbol                             UGP2           IL1R2           HKDC1  \
# Gene_ensembl_id              ENSG00000169764 ENSG00000115590 ENSG00000156510
# Sample_ID
# TCGA-AA-3867-01A-01R-1022-07       15.509306        1.729770       12.752686
# TCGA-CA-6719-01A-11R-1839-07       13.800729        1.097672       18.532900
# TCGA-NH-A50V-01A-11R-A28H-07       16.107688        0.570912        4.204533
# TCGA-AA-A01C-01A-01R-A00A-07       11.142595        0.479973       20.432585
# TCGA-AA-A02F-01A-01R-A089-07       13.780305        0.822586       19.322412
# ...                                      ...             ...             ...
# TCGA-A6-2682-11A-01R-A32Z-07       57.037639       10.666862       11.973689
# TCGA-AA-3522-11A-01R-A32Z-07       74.743021       18.051094        9.957414
# TCGA-AA-3662-11A-01R-1723-07       45.311255       49.908591        2.679323
# TCGA-AA-3520-11A-01R-A32Z-07       70.222246       16.308686       14.142560
# TCGA-A6-2685-11A-01R-A32Z-07       84.654478       19.729591       10.748853
#
# Gene_symbol                             CD44 Cancer
# Gene_ensembl_id              ENSG00000026508 Cancer
# Sample_ID
# TCGA-AA-3867-01A-01R-1022-07       49.437336      1
# TCGA-CA-6719-01A-11R-1839-07       26.181544      1
# TCGA-NH-A50V-01A-11R-A28H-07       43.585652      1
# TCGA-AA-A01C-01A-01R-A00A-07       25.303669      1
# TCGA-AA-A02F-01A-01R-A089-07       57.488870      1
# ...                                      ...    ...
# TCGA-A6-2682-11A-01R-A32Z-07       12.996430      0
# TCGA-AA-3522-11A-01R-A32Z-07       11.233170      0
# TCGA-AA-3662-11A-01R-1723-07       15.903117      0
# TCGA-AA-3520-11A-01R-A32Z-07       12.256530      0
# TCGA-A6-2685-11A-01R-A32Z-07       12.430892      0
#
# [519 rows x 14 columns]

# %%
#Save the isoform_switch filtered FPKM file to a csv
FPKM_protein_isoform.to_csv(MAF_file.split('/')[5]+'_FPKM_protein_isoform_filtered.csv',sep='\t')
