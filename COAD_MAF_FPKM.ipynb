# %%
import pandas as pd
import seaborn as sns 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#Files used - replace with the corresponding files uploaded to Git since I am loading them from my computer here

#MAF file
TCGA_MAF = '/Users/jake/OneDrive - University of Glasgow/Project - Practice/COAD/70cb1255-ec99-4c08-b482-415f8375be3f/TCGA.COAD.muse.70cb1255-ec99-4c08-b482-415f8375be3f.DR-10.0.somatic.maf'

#FPKM files - FPKM values for COAD from TCGA, acquired through TCGAbiolinks in R (see R code and document)
tumour_FPKM_file = '/Users/jake/OneDrive - University of Glasgow/Project - Practice/TCGA_R_FPKM/FPKM_COAD_tumour'
normal_FPKM_file = '/Users/jake/OneDrive - University of Glasgow/Project - Practice/TCGA_R_FPKM/FPKM_COAD_normal'

# %%
#Load MAF file for somatic COAD mutations from TCGA
#Skip 'comment' rows that start with #, low_memory = False for dtype error

MAF = pd.read_csv(TCGA_MAF,sep='\t',comment='#',low_memory=False)

# %%
MAF.head()
# Out:
#   Hugo_Symbol  Entrez_Gene_Id Center NCBI_Build Chromosome  Start_Position  \
# 0      ATAD3B           83858    BCM     GRCh38       chr1         1485803
# 1       PLCH2            9651    BCM     GRCh38       chr1         2487195
# 2        CHD5           26038    BCM     GRCh38       chr1         6146395
# 3      IFNLR1          163702    BCM     GRCh38       chr1        24159060
# 4      YTHDF2           51441    BCM     GRCh38       chr1        28769136
#
#    End_Position Strand Variant_Classification Variant_Type  ... FILTER  \
# 0       1485803      +      Nonsense_Mutation          SNP  ...   PASS
# 1       2487195      +                 Silent          SNP  ...   PASS
# 2       6146395      +      Missense_Mutation          SNP  ...   PASS
# 3      24159060      +      Missense_Mutation          SNP  ...   PASS
# 4      28769136      +                  3'UTR          SNP  ...   PASS
#
#        CONTEXT                            src_vcf_id  \
# 0  TCAGTCGACCC  9130f121-b7ce-460f-b90c-8e31add6cd10
# 1  AGGAGCCCTGC  9130f121-b7ce-460f-b90c-8e31add6cd10
# 2  AGTTGCGATAC  9130f121-b7ce-460f-b90c-8e31add6cd10
# 3  GGCCCGTGGCA  9130f121-b7ce-460f-b90c-8e31add6cd10
# 4  AAAAAAAGAAA  9130f121-b7ce-460f-b90c-8e31add6cd10
#
#                          tumor_bam_uuid                       normal_bam_uuid  \
# 0  7de9d9e2-c4a4-4311-826f-973cb7987c66  861ad835-790a-47ad-8c03-06f7eb7b5710
# 1  7de9d9e2-c4a4-4311-826f-973cb7987c66  861ad835-790a-47ad-8c03-06f7eb7b5710
# 2  7de9d9e2-c4a4-4311-826f-973cb7987c66  861ad835-790a-47ad-8c03-06f7eb7b5710
# 3  7de9d9e2-c4a4-4311-826f-973cb7987c66  861ad835-790a-47ad-8c03-06f7eb7b5710
# 4  7de9d9e2-c4a4-4311-826f-973cb7987c66  861ad835-790a-47ad-8c03-06f7eb7b5710
#
#                                 case_id GDC_FILTER                   COSMIC  \
# 0  7a70f061-9a6f-408e-a416-7f5295ceba3b        NaN              COSM1333470
# 1  7a70f061-9a6f-408e-a416-7f5295ceba3b        NaN  COSM1340725;COSM1340726
# 2  7a70f061-9a6f-408e-a416-7f5295ceba3b        NaN               COSM911251
# 3  7a70f061-9a6f-408e-a416-7f5295ceba3b        NaN              COSM1340840
# 4  7a70f061-9a6f-408e-a416-7f5295ceba3b        NaN                      NaN
#
#    MC3_Overlap GDC_Validation_Status
# 0         True               Unknown
# 1         True               Unknown
# 2         True               Unknown
# 3         True               Unknown
# 4         True               Unknown
#
# [5 rows x 120 columns]

# %%
#IMPACT col is the VEP status, with HIGH and MODERATE displaying variants that affect proteins
#Create new MAF DF with these values extracted

MAF_VEP_protein = MAF[(MAF['IMPACT'] == 'HIGH') | (MAF['IMPACT'] == 'MODERATE')]

# %%
#dbSNP_RS col is the rs-IDs from the dbSNP database, "novel" if not found in any database used, 
#or null if there is no dbSNP record, but it is found in other databases

MAF_VEP_protein['dbSNP_RS'].value_counts()
# Out:
# novel          37143
# rs121913529       84
# rs113488022       44
# rs112445441       30
# rs104886003       29
#                ...
# rs199510940        1
# rs146229969        1
# rs746300859        1
# rs764418026        1
# rs778832697        1
# Name: dbSNP_RS, Length: 32918, dtype: int64

# %%
#Aliquot barcode for tumour sample in col 'Tumor_Sample_Barcode'

MAF_VEP_protein['Tumor_Sample_Barcode'].value_counts()
# Out:
# TCGA-AA-A010-01A-01D-A17O-10    7267
# TCGA-CA-6717-01A-11D-1835-10    6899
# TCGA-AZ-4315-01A-01D-1408-10    5841
# TCGA-AA-3984-01A-02D-1981-10    4406
# TCGA-AA-A00N-01A-02D-A17O-10    4181
#                                 ...
# TCGA-F4-6704-01A-11D-1835-10      32
# TCGA-CM-5863-01A-21D-1835-10      32
# TCGA-A6-5664-01A-21D-1835-10      29
# TCGA-CA-5255-01A-11D-1835-10      24
# TCGA-AZ-4323-01A-21D-1835-10      20
# Name: Tumor_Sample_Barcode, Length: 399, dtype: int64

# %%
#Aliquot barcode for the matched normal sample in col 'Matched_Norm_Sample_Barcode'

MAF_VEP_protein['Matched_Norm_Sample_Barcode'].value_counts()
# Out:
# TCGA-AA-A010-10A-01D-A17O-10    7267
# TCGA-CA-6717-10A-01D-1835-10    6899
# TCGA-AZ-4315-10A-01D-1408-10    5841
# TCGA-AA-3984-10A-01D-1982-10    4406
# TCGA-AA-A00N-10A-01D-A17O-10    4181
#                                 ...
# TCGA-AA-3972-10A-01W-0999-10      32
# TCGA-CM-5863-10A-01D-1835-10      32
# TCGA-A6-5664-10A-01D-1835-10      29
# TCGA-CA-5255-10A-01D-1835-10      24
# TCGA-AZ-4323-10A-01D-1835-10      20
# Name: Matched_Norm_Sample_Barcode, Length: 399, dtype: int64

# %%
#Each tumour sample seems to have a tumour sample with a matched normal

MAF_VEP_protein[['Tumor_Sample_Barcode','Matched_Norm_Sample_Barcode']].head()
# Out:
#             Tumor_Sample_Barcode   Matched_Norm_Sample_Barcode
# 0   TCGA-CK-6751-01A-11D-1835-10  TCGA-CK-6751-10A-01D-1835-10
# 2   TCGA-CK-6751-01A-11D-1835-10  TCGA-CK-6751-10A-01D-1835-10
# 3   TCGA-CK-6751-01A-11D-1835-10  TCGA-CK-6751-10A-01D-1835-10
# 8   TCGA-CK-6751-01A-11D-1835-10  TCGA-CK-6751-10A-01D-1835-10
# 10  TCGA-CK-6751-01A-11D-1835-10  TCGA-CK-6751-10A-01D-1835-10

# %%
#Load the FPKM files

tumour_FPKM = pd.read_csv(tumour_FPKM_file)
normal_FPKM = pd.read_csv(normal_FPKM_file)

# %%
tumour_FPKM.head()
# Out:
#         Unnamed: 0 Gene_symbol  TCGA-AA-3867-01A-01R-1022-07  \
# 0  ENSG00000000003      TSPAN6                     60.706756
# 1  ENSG00000000005        TNMD                      0.065378
# 2  ENSG00000000419        DPM1                     53.021975
# 3  ENSG00000000457       SCYL3                      1.850407
# 4  ENSG00000000460    C1orf112                      1.234814
#
#    TCGA-CA-6719-01A-11R-1839-07  TCGA-NH-A50V-01A-11R-A28H-07  \
# 0                     62.310848                     28.054054
# 1                      0.768211                      0.087677
# 2                     49.744823                     39.211929
# 3                      1.996215                      2.578204
# 4                      1.937095                      0.980064
#
#    TCGA-AA-A01C-01A-01R-A00A-07  TCGA-AA-A02F-01A-01R-A089-07  \
# 0                     43.148277                     49.288566
# 1                      0.488598                      0.058151
# 2                     48.717118                     47.276633
# 3                      1.157164                      2.659188
# 4                      1.235927                      4.581492
#
#    TCGA-AA-A03F-01A-11R-A16W-07  TCGA-AA-A00O-01A-02R-A089-07  \
# 0                      6.029851                     15.781543
# 1                      1.005012                      0.000000
# 2                      6.233657                     59.815651
# 3                      1.140148                      2.379475
# 4                      0.637249                      0.782066
#
#    TCGA-AZ-4615-01A-01R-1410-07  ...  TCGA-A6-6138-01A-11R-1774-07  \
# 0                     20.084270  ...                     43.579197
# 1                      0.024084  ...                      0.699250
# 2                     30.839994  ...                     54.079416
# 3                      1.706928  ...                      2.972966
# 4                      1.124192  ...                      2.282533
#
#    TCGA-A6-2685-01A-01R-1410-07  TCGA-QG-A5YX-01A-11R-A28H-07  \
# 0                     31.906153                     47.325870
# 1                      2.392969                      0.602650
# 2                     23.685697                     39.968203
# 3                      1.609248                      2.675526
# 4                      0.858440                      1.899230
#
#    TCGA-AY-A54L-01A-11R-A28H-07  TCGA-A6-2671-01A-01R-1410-07  \
# 0                     74.750409                     22.444239
# 1                      0.452964                      0.265327
# 2                     85.633379                     43.145615
# 3                      1.867057                      1.201758
# 4                      2.791183                      2.154205
#
#    TCGA-NH-A8F8-01A-72R-A41B-07  TCGA-CM-5863-01A-21R-1839-07  \
# 0                     27.192429                     33.208506
# 1                      0.273898                      5.345912
# 2                     81.924110                     20.560575
# 3                      2.562697                      2.301442
# 4                      1.504133                      0.872320
#
#    TCGA-A6-3809-01A-01R-A278-07  TCGA-D5-6932-01A-11R-1928-07  \
# 0                     18.076069                     29.713629
# 1                      0.013534                      0.199307
# 2                     53.239013                     52.921301
# 3                      2.823902                      1.946377
# 4                      3.005428                      1.630099
#
#    TCGA-AA-3675-01A-02R-0905-07
# 0                     25.791329
# 1                      0.000000
# 2                     37.169671
# 3                      4.566399
# 4                      3.124514
#
# [5 rows x 480 columns]

# %%
#rename first col name in both DF

tumour_FPKM.rename(columns={'Unnamed: 0':'Gene_ensembl_id'},inplace=True)
normal_FPKM.rename(columns={'Unnamed: 0':'Gene_ensembl_id'},inplace=True)

# %%
tumour_FPKM.head()
# Out:
#    Gene_ensembl_id Gene_symbol  TCGA-AA-3867-01A-01R-1022-07  \
# 0  ENSG00000000003      TSPAN6                     60.706756
# 1  ENSG00000000005        TNMD                      0.065378
# 2  ENSG00000000419        DPM1                     53.021975
# 3  ENSG00000000457       SCYL3                      1.850407
# 4  ENSG00000000460    C1orf112                      1.234814
#
#    TCGA-CA-6719-01A-11R-1839-07  TCGA-NH-A50V-01A-11R-A28H-07  \
# 0                     62.310848                     28.054054
# 1                      0.768211                      0.087677
# 2                     49.744823                     39.211929
# 3                      1.996215                      2.578204
# 4                      1.937095                      0.980064
#
#    TCGA-AA-A01C-01A-01R-A00A-07  TCGA-AA-A02F-01A-01R-A089-07  \
# 0                     43.148277                     49.288566
# 1                      0.488598                      0.058151
# 2                     48.717118                     47.276633
# 3                      1.157164                      2.659188
# 4                      1.235927                      4.581492
#
#    TCGA-AA-A03F-01A-11R-A16W-07  TCGA-AA-A00O-01A-02R-A089-07  \
# 0                      6.029851                     15.781543
# 1                      1.005012                      0.000000
# 2                      6.233657                     59.815651
# 3                      1.140148                      2.379475
# 4                      0.637249                      0.782066
#
#    TCGA-AZ-4615-01A-01R-1410-07  ...  TCGA-A6-6138-01A-11R-1774-07  \
# 0                     20.084270  ...                     43.579197
# 1                      0.024084  ...                      0.699250
# 2                     30.839994  ...                     54.079416
# 3                      1.706928  ...                      2.972966
# 4                      1.124192  ...                      2.282533
#
#    TCGA-A6-2685-01A-01R-1410-07  TCGA-QG-A5YX-01A-11R-A28H-07  \
# 0                     31.906153                     47.325870
# 1                      2.392969                      0.602650
# 2                     23.685697                     39.968203
# 3                      1.609248                      2.675526
# 4                      0.858440                      1.899230
#
#    TCGA-AY-A54L-01A-11R-A28H-07  TCGA-A6-2671-01A-01R-1410-07  \
# 0                     74.750409                     22.444239
# 1                      0.452964                      0.265327
# 2                     85.633379                     43.145615
# 3                      1.867057                      1.201758
# 4                      2.791183                      2.154205
#
#    TCGA-NH-A8F8-01A-72R-A41B-07  TCGA-CM-5863-01A-21R-1839-07  \
# 0                     27.192429                     33.208506
# 1                      0.273898                      5.345912
# 2                     81.924110                     20.560575
# 3                      2.562697                      2.301442
# 4                      1.504133                      0.872320
#
#    TCGA-A6-3809-01A-01R-A278-07  TCGA-D5-6932-01A-11R-1928-07  \
# 0                     18.076069                     29.713629
# 1                      0.013534                      0.199307
# 2                     53.239013                     52.921301
# 3                      2.823902                      1.946377
# 4                      3.005428                      1.630099
#
#    TCGA-AA-3675-01A-02R-0905-07
# 0                     25.791329
# 1                      0.000000
# 2                     37.169671
# 3                      4.566399
# 4                      3.124514
#
# [5 rows x 480 columns]

# %%
#All FPKM samples seem to come from centre 07, whereas the MAF samples come from centre 10
# => to see if FPKM and MAF samples match split Id's up to and including participant Id

#First for tumour samples
MAF_VEP_protein_tumour = MAF_VEP_protein.copy()
MAF_VEP_protein_tumour['Tumor_Sample_Barcode'] = MAF_VEP_protein['Tumor_Sample_Barcode'].apply(lambda x: '-'.join((x.split('-')[0:3])))

# %%
MAF_VEP_protein_tumour['Tumor_Sample_Barcode'].value_counts()
# Out:
# TCGA-AA-A010    7267
# TCGA-CA-6717    6899
# TCGA-AZ-4315    5841
# TCGA-AA-3984    4406
# TCGA-AA-A00N    4181
#                 ...
# TCGA-CM-5863      32
# TCGA-F4-6704      32
# TCGA-A6-5664      29
# TCGA-CA-5255      24
# TCGA-AZ-4323      20
# Name: Tumor_Sample_Barcode, Length: 399, dtype: int64

# %%
#Do the same for the FPKM tumour file

tumour_FPKM_sample = tumour_FPKM.copy()

# %%
#Rename rows upto participant id

tumour_FPKM_sample.rename(columns= lambda x: '-'.join((x.split('-')[0:3])),inplace=True)

# %%
tumour_FPKM_sample.head()
# Out:
#    Gene_ensembl_id Gene_symbol  TCGA-AA-3867  TCGA-CA-6719  TCGA-NH-A50V  \
# 0  ENSG00000000003      TSPAN6     60.706756     62.310848     28.054054
# 1  ENSG00000000005        TNMD      0.065378      0.768211      0.087677
# 2  ENSG00000000419        DPM1     53.021975     49.744823     39.211929
# 3  ENSG00000000457       SCYL3      1.850407      1.996215      2.578204
# 4  ENSG00000000460    C1orf112      1.234814      1.937095      0.980064
#
#    TCGA-AA-A01C  TCGA-AA-A02F  TCGA-AA-A03F  TCGA-AA-A00O  TCGA-AZ-4615  ...  \
# 0     43.148277     49.288566      6.029851     15.781543     20.084270  ...
# 1      0.488598      0.058151      1.005012      0.000000      0.024084  ...
# 2     48.717118     47.276633      6.233657     59.815651     30.839994  ...
# 3      1.157164      2.659188      1.140148      2.379475      1.706928  ...
# 4      1.235927      4.581492      0.637249      0.782066      1.124192  ...
#
#    TCGA-A6-6138  TCGA-A6-2685  TCGA-QG-A5YX  TCGA-AY-A54L  TCGA-A6-2671  \
# 0     43.579197     31.906153     47.325870     74.750409     22.444239
# 1      0.699250      2.392969      0.602650      0.452964      0.265327
# 2     54.079416     23.685697     39.968203     85.633379     43.145615
# 3      2.972966      1.609248      2.675526      1.867057      1.201758
# 4      2.282533      0.858440      1.899230      2.791183      2.154205
#
#    TCGA-NH-A8F8  TCGA-CM-5863  TCGA-A6-3809  TCGA-D5-6932  TCGA-AA-3675
# 0     27.192429     33.208506     18.076069     29.713629     25.791329
# 1      0.273898      5.345912      0.013534      0.199307      0.000000
# 2     81.924110     20.560575     53.239013     52.921301     37.169671
# 3      2.562697      2.301442      2.823902      1.946377      4.566399
# 4      1.504133      0.872320      3.005428      1.630099      3.124514
#
# [5 rows x 480 columns]

# %%
#Compare sample ids between the MAF and tumour_FPKM dataframe using set function since doesn't allow duplicate values
#Returns list of sample ids not found in the FPKM DF

non_matching_samples_tumour = list(set(MAF_VEP_protein_tumour['Tumor_Sample_Barcode']) - set(tumour_FPKM_sample.iloc[:,2:].columns))
non_matching_samples_tumour
# Out:
# ['TCGA-AZ-4681', 'TCGA-AA-3695', 'TCGA-AA-3967']

# %%
#Drop the rows containing the non matching samples from the MAF DF using .query

MAF_VEP_protein_tumour =  MAF_VEP_protein_tumour.query('Tumor_Sample_Barcode not in @non_matching_samples_tumour')

# %%
MAF_VEP_protein_tumour[MAF_VEP_protein_tumour['Tumor_Sample_Barcode'] =='TCGA-AA-3695']
# Out:
# Empty DataFrame
# Columns: [Hugo_Symbol, Entrez_Gene_Id, Center, NCBI_Build, Chromosome, Start_Position, End_Position, Strand, Variant_Classification, Variant_Type, Reference_Allele, Tumor_Seq_Allele1, Tumor_Seq_Allele2, dbSNP_RS, dbSNP_Val_Status, Tumor_Sample_Barcode, Matched_Norm_Sample_Barcode, Match_Norm_Seq_Allele1, Match_Norm_Seq_Allele2, Tumor_Validation_Allele1, Tumor_Validation_Allele2, Match_Norm_Validation_Allele1, Match_Norm_Validation_Allele2, Verification_Status, Validation_Status, Mutation_Status, Sequencing_Phase, Sequence_Source, Validation_Method, Score, BAM_File, Sequencer, Tumor_Sample_UUID, Matched_Norm_Sample_UUID, HGVSc, HGVSp, HGVSp_Short, Transcript_ID, Exon_Number, t_depth, t_ref_count, t_alt_count, n_depth, n_ref_count, n_alt_count, all_effects, Allele, Gene, Feature, Feature_type, One_Consequence, Consequence, cDNA_position, CDS_position, Protein_position, Amino_acids, Codons, Existing_variation, ALLELE_NUM, DISTANCE, TRANSCRIPT_STRAND, SYMBOL, SYMBOL_SOURCE, HGNC_ID, BIOTYPE, CANONICAL, CCDS, ENSP, SWISSPROT, TREMBL, UNIPARC, RefSeq, SIFT, PolyPhen, EXON, INTRON, DOMAINS, GMAF, AFR_MAF, AMR_MAF, ASN_MAF, EAS_MAF, EUR_MAF, SAS_MAF, AA_MAF, EA_MAF, CLIN_SIG, SOMATIC, PUBMED, MOTIF_NAME, MOTIF_POS, HIGH_INF_POS, MOTIF_SCORE_CHANGE, IMPACT, PICK, VARIANT_CLASS, TSL, HGVS_OFFSET, PHENO, MINIMISED, ...]
# Index: []
#
# [0 rows x 120 columns]

# %%
#Check that we have no mismatching sample Ids ... => len = 0

len(list(set(MAF_VEP_protein_tumour['Tumor_Sample_Barcode']) - set(tumour_FPKM_sample.columns)))
# Out:
# 0

# %%
#Create list of final cols required in FPKM

final_cols_tumour = list(MAF_VEP_protein_tumour['Tumor_Sample_Barcode'].unique())
final_cols_tumour.extend(['Gene_ensembl_id','Gene_symbol'])

# %%
#drop cols not in final list 

tumour_FPKM_sample.drop(columns= [col for col in tumour_FPKM_sample if col not in final_cols_tumour],inplace=True)

# %%
tumour_FPKM_sample.head()
# Out:
#    Gene_ensembl_id Gene_symbol  TCGA-AA-3867  TCGA-CA-6719  TCGA-NH-A50V  \
# 0  ENSG00000000003      TSPAN6     60.706756     62.310848     28.054054
# 1  ENSG00000000005        TNMD      0.065378      0.768211      0.087677
# 2  ENSG00000000419        DPM1     53.021975     49.744823     39.211929
# 3  ENSG00000000457       SCYL3      1.850407      1.996215      2.578204
# 4  ENSG00000000460    C1orf112      1.234814      1.937095      0.980064
#
#    TCGA-AA-A01C  TCGA-AA-A02F  TCGA-AA-A03F  TCGA-AZ-4615  TCGA-AA-3854  ...  \
# 0     43.148277     49.288566      6.029851     20.084270     18.393394  ...
# 1      0.488598      0.058151      1.005012      0.024084      0.045789  ...
# 2     48.717118     47.276633      6.233657     30.839994     21.438009  ...
# 3      1.157164      2.659188      1.140148      1.706928      2.956078  ...
# 4      1.235927      4.581492      0.637249      1.124192      1.976735  ...
#
#    TCGA-A6-6138  TCGA-A6-2685  TCGA-QG-A5YX  TCGA-AY-A54L  TCGA-A6-2671  \
# 0     43.579197     31.906153     47.325870     74.750409     22.444239
# 1      0.699250      2.392969      0.602650      0.452964      0.265327
# 2     54.079416     23.685697     39.968203     85.633379     43.145615
# 3      2.972966      1.609248      2.675526      1.867057      1.201758
# 4      2.282533      0.858440      1.899230      2.791183      2.154205
#
#    TCGA-NH-A8F8  TCGA-CM-5863  TCGA-A6-3809  TCGA-D5-6932  TCGA-AA-3675
# 0     27.192429     33.208506     18.076069     29.713629     25.791329
# 1      0.273898      5.345912      0.013534      0.199307      0.000000
# 2     81.924110     20.560575     53.239013     52.921301     37.169671
# 3      2.562697      2.301442      2.823902      1.946377      4.566399
# 4      1.504133      0.872320      3.005428      1.630099      3.124514
#
# [5 rows x 420 columns]

# %%
#Check FPKM cols match up to sample ids in MAF => all that should remain should be gene ensembl and symbol col

set(tumour_FPKM_sample.columns) - set(MAF_VEP_protein_tumour['Tumor_Sample_Barcode'])
# Out:
# {'Gene_ensembl_id', 'Gene_symbol'}

# %%
#Do the same process for matching normal samples

# %%
#Normal FPKM rename columns

normal_FPKM_sample = normal_FPKM.copy()
normal_FPKM_sample.rename(columns= lambda x: '-'.join((x.split('-')[0:3])),inplace=True)
normal_FPKM_sample.head()
# Out:
#    Gene_ensembl_id Gene_symbol  TCGA-AA-3534  TCGA-AZ-6598  TCGA-A6-2678  \
# 0  ENSG00000000003      TSPAN6     21.875041     25.857174     30.247957
# 1  ENSG00000000005        TNMD      0.705639      0.735095      0.659471
# 2  ENSG00000000419        DPM1     19.428661     20.021853     20.953200
# 3  ENSG00000000457       SCYL3      2.815292      2.174283      2.885359
# 4  ENSG00000000460    C1orf112      0.700505      0.886138      0.673826
#
#    TCGA-AA-3514  TCGA-A6-5667  TCGA-AZ-6603  TCGA-AA-3713  TCGA-AA-3655  ...  \
# 0     35.900789     27.576637     18.098814     24.464751     36.113444  ...
# 1      0.956285      0.560075      0.467306      1.209251      0.415819  ...
# 2     22.699088     21.024849     21.407599     48.348166     31.393500  ...
# 3      2.363508      2.719953      2.018772      3.232633      2.869292  ...
# 4      1.144002      0.680031      0.791986      1.084764      0.777887  ...
#
#    TCGA-A6-5665  TCGA-A6-2684  TCGA-AZ-6599  TCGA-AA-3712  TCGA-AA-3697  \
# 0     19.274104     23.841193     34.069906     22.731096     24.817074
# 1      0.603394      0.576547      0.183540      0.341408      0.269357
# 2     19.630690     19.945078     19.145061     22.067904     31.367703
# 3      2.702307      2.530088      2.103660      3.873146      2.265448
# 4      0.484447      0.514032      0.970638      0.721590      1.305029
#
#    TCGA-A6-2682  TCGA-AA-3522  TCGA-AA-3662  TCGA-AA-3520  TCGA-A6-2685
# 0     26.814931     20.538710     43.168339     18.687427     23.158600
# 1      0.712037      0.712653      0.527980      0.421246      0.902174
# 2     22.735246     22.497485     26.527291     21.527560     21.845183
# 3      2.672642      2.923599      3.734924      2.676826      2.765696
# 4      0.723451      1.023061      0.630269      0.644070      1.159835
#
# [5 rows x 43 columns]

# %%
#Rename MAF Matched_Norm_Sample_Barcode column

MAF_VEP_protein_normal = MAF_VEP_protein.copy()
MAF_VEP_protein_normal['Matched_Norm_Sample_Barcode'] = MAF_VEP_protein['Matched_Norm_Sample_Barcode'].apply(lambda x: '-'.join((x.split('-')[0:3])))

# %%
MAF_VEP_protein_normal['Matched_Norm_Sample_Barcode'].value_counts()
# Out:
# TCGA-AA-A010    7267
# TCGA-CA-6717    6899
# TCGA-AZ-4315    5841
# TCGA-AA-3984    4406
# TCGA-AA-A00N    4181
#                 ...
# TCGA-CM-5863      32
# TCGA-F4-6704      32
# TCGA-A6-5664      29
# TCGA-CA-5255      24
# TCGA-AZ-4323      20
# Name: Matched_Norm_Sample_Barcode, Length: 399, dtype: int64

# %%
non_matching_samples_normal = list(set(MAF_VEP_protein_normal['Matched_Norm_Sample_Barcode']) - set(normal_FPKM_sample.iloc[:,2:].columns))

# %%
#Drop the rows containing the non matching samples from the MAF DF using .query

MAF_VEP_protein_normal =  MAF_VEP_protein_normal.query('Matched_Norm_Sample_Barcode not in @non_matching_samples_normal')

# %%
#Check that we have no mismatching sample Ids ... => len = 0

len(list(set(MAF_VEP_protein_normal['Matched_Norm_Sample_Barcode']) - set(normal_FPKM_sample.columns)))
# Out:
# 0

# %%
#Create list of final cols required in FPKM

final_cols_normal = list(MAF_VEP_protein_normal['Matched_Norm_Sample_Barcode'].unique())
final_cols_normal.extend(['Gene_ensembl_id','Gene_symbol'])

# %%
#drop cols not in final list 

normal_FPKM_sample.drop(columns= [col for col in normal_FPKM_sample if col not in final_cols_normal],inplace=True)

# %%
normal_FPKM_sample.head()
# Out:
#    Gene_ensembl_id Gene_symbol  TCGA-AZ-6598  TCGA-A6-5667  TCGA-AZ-6603  \
# 0  ENSG00000000003      TSPAN6     25.857174     27.576637     18.098814
# 1  ENSG00000000005        TNMD      0.735095      0.560075      0.467306
# 2  ENSG00000000419        DPM1     20.021853     21.024849     21.407599
# 3  ENSG00000000457       SCYL3      2.174283      2.719953      2.018772
# 4  ENSG00000000460    C1orf112      0.886138      0.680031      0.791986
#
#    TCGA-AA-3713  TCGA-AA-3655  TCGA-AA-3489  TCGA-AA-3660  TCGA-AA-3663  ...  \
# 0     24.464751     36.113444     35.956685     29.191332     18.200302  ...
# 1      1.209251      0.415819      0.477041      0.592175      0.727522  ...
# 2     48.348166     31.393500     39.133548     31.131119     21.327928  ...
# 3      3.232633      2.869292      3.344046      3.271410      2.408914  ...
# 4      1.084764      0.777887      0.941220      0.874086      0.811366  ...
#
#    TCGA-A6-2686  TCGA-F4-6704  TCGA-A6-5665  TCGA-A6-2684  TCGA-AZ-6599  \
# 0     16.622676     21.215679     19.274104     23.841193     34.069906
# 1      0.541646      0.913592      0.603394      0.576547      0.183540
# 2     22.022668     28.874312     19.630690     19.945078     19.145061
# 3      2.700505      2.086699      2.702307      2.530088      2.103660
# 4      0.838983      1.328217      0.484447      0.514032      0.970638
#
#    TCGA-AA-3712  TCGA-AA-3697  TCGA-A6-2682  TCGA-AA-3662  TCGA-A6-2685
# 0     22.731096     24.817074     26.814931     43.168339     23.158600
# 1      0.341408      0.269357      0.712037      0.527980      0.902174
# 2     22.067904     31.367703     22.735246     26.527291     21.845183
# 3      3.873146      2.265448      2.672642      3.734924      2.765696
# 4      0.721590      1.305029      0.723451      0.630269      1.159835
#
# [5 rows x 30 columns]

# %%
#Check FPKM cols match up to sample ids in MAF => all that should remain should be gene ensembl and symbol col

set(normal_FPKM_sample.columns) - set(MAF_VEP_protein_normal['Matched_Norm_Sample_Barcode'])
# Out:
# {'Gene_ensembl_id', 'Gene_symbol'}
